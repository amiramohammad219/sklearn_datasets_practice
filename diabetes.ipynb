# %%
from sklearn.datasets import load_diabetes

# %%
data=load_diabetes()

# %%
x=data.data

# %%
x.shape
# Out:
# (442, 10)

# %%
x[20,:10]
# Out:
# array([-0.04910502, -0.04464164, -0.05686312, -0.04354178, -0.04559945,
#        -0.04327577,  0.00077881, -0.03949338, -0.01189685,  0.01549073])

# %%
data.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
#y_data
y=data.target

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
y.shape
# Out:
# (442,)

# %%
y[1:]
# Out:
# array([ 75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,  69.,
#        179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,  68.,
#        245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,  87.,
#         65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92., 259.,
#         53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182., 128.,
#         52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163., 150.,
#         97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170., 200.,
#        252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,  42.,
#        111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,  83.,
#        128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81., 104.,
#         59., 246., 297., 258., 229., 275., 281., 179., 200., 200., 173.,
#        180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158., 107.,
#         83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,  60.,
# ...
