# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=100,n_features=5,n_classes=2,shuffle=True)

# %%
x.shape
# Out:
# (100, 5)

# %%
y.shape
# Out:
# (100,)

# %%
x[10:]
# Out:
# array([[ 1.51970726,  1.94121073, -2.59136245,  2.29822039,  2.27808218],
#        [ 0.83637555, -3.03856293,  0.75698632, -1.33395899,  0.15067366],
#        [-0.53234409, -0.75135213, -0.04976935, -0.1672925 ,  0.30417763],
#        [ 1.23806945,  0.90423907, -0.82441342,  0.80800777,  0.63008371],
#        [-0.92672113,  2.56466904, -2.25212931,  2.23264031,  1.69006327],
#        [-0.57752659, -0.94181855, -0.98602577,  0.42395538,  1.42174667],
#        [ 1.08627109,  0.02154044, -2.10804991,  1.4519867 ,  2.36755972],
#        [ 0.23241138, -0.95924905,  0.05519727, -0.29504093,  0.25458727],
#        [-0.72457032,  0.95718944,  0.40273337, -0.01967111, -0.76975615],
#        [-0.00830648,  3.19322688, -0.8535265 ,  1.44165482, -0.09299677],
#        [-0.54977145,  1.40763942,  0.9836038 , -0.29740792, -1.572843  ],
#        [-0.21783331, -1.14574949, -1.19277482,  0.51112042,  1.72198765],
#        [ 0.46619966,  1.13611103, -0.0565106 ,  0.34335836, -0.31151167],
# ...

# %%
y[:10]
# Out:
# array([0, 1, 0, 1, 1, 0, 0, 0, 1, 0])
